# %% [markdown]
# # Stage 3: Clustering Deep Dive
#
# This notebook checks whether we can recreate the published clustering logic, then asks whether a more detailed persona view helps us tell a sharper story.

# %%
import sys
import warnings
from pathlib import Path
from IPython.display import display

warnings.filterwarnings("ignore")

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "scripts"))

from analysis_utils import notebook_setup

df = notebook_setup()
print(f"Loaded prepared analysis frame with shape: {df.shape}")
# Out:
# Loaded prepared analysis frame with shape: (930, 96)

# %% [markdown]
# ## Section 3.1 - Reproduce the official UMAP plus HDBSCAN structure

# %%
from stage3_clustering_deep_dive import run_reproduction

reproduction_results = run_reproduction(df)
display(reproduction_results["reproduction_grid"].head(10))
# Out:
#     n_neighbors  min_dist  min_cluster_size  min_samples  cluster_count  \
# 0            15       0.0                60            5              4
# 2            15       0.0                90            5              4
# 1            15       0.0                60           15              4
# 3            15       0.0                90           15              4
# 6            15       0.1                60            5              4
# 8            15       0.1                90            5              4
# 7            15       0.1                60           15              4
# 13           30       0.0                60           15              3
# 15           30       0.0                90           15              3
# 17           30       0.0               120           15              3
#
#     adjusted_rand_index
# 0              0.238831
# 2              0.238831
# 1              0.233080
# 3              0.233080
# 6              0.229646
# 8              0.229646
# 7              0.227395
# 13             0.226936
# 15             0.226936
# 17             0.226936

# %% [markdown]
# ## Section 3.2 - Build and profile an expanded persona set

# %%
from stage3_clustering_deep_dive import run_persona_analysis

persona_results = run_persona_analysis(df)
print(f"Chosen persona count: {persona_results['chosen_k']}")
display(persona_results["silhouette"])
display(persona_results["persona_summary"])
# Out:
# Chosen persona count: 5
#    k  silhouette_score
# 0  3          0.118536
# 1  4          0.098206
# 2  5          0.096475
# 3  6          0.090387
# 4  7          0.078398
#    persona_id  count  pct_of_sample  infra_score  ai_use_count  ai_want_count  \
# 0           2    142      15.268817     3.760563      4.105634       5.746479
# 1           0    151      16.236559     3.052980      2.874172       6.000000
# 2           3    108      11.612903     2.555556      1.611111       1.759259
# 3           1    319      34.301075     1.623824      1.272727       4.288401
# 4           4    210      22.580645     1.795238      0.428571       0.452381
#
#    want_use_gap  person_ai_comfort_raw  risk_count role_mode    region_mode  \
# 0      1.640845               8.367647    3.711268    Leader  North America
# 1      3.125828               7.489655    3.609272    Leader  North America
# 2      0.148148               7.057143    2.638889    Leader  North America
# 3      3.015674               6.529801    3.153605    Leader  North America
# 4      0.023810               4.210526    2.523810    Leader  North America
#
#     cluster_mode  [U] Generat  [U] Predict  [W] Predict        persona_name  \
# 0   AI Consumers     0.845070     0.330986     0.816901      Quiet Builders
# 1   AI Consumers     0.735099     0.218543     0.913907    Activation-Ready
# 2   AI Consumers     0.500000     0.101852     0.240741  Steady Pragmatists
# 3   AI Consumers     0.573668     0.021944     0.608150  Prediction-Curious
# 4  Late Adopters     0.157143     0.028571     0.033333     Burned and Wary
#
#                                                story  \
# 0  These groups already have the basics, so their...
# 1  This group moves steadily, with moderate deman...
# 2  This group moves steadily, with moderate deman...
# 3  They are aiming at advanced use cases before t...
# 4  Skepticism here looks learned, not abstract, w...
#
#                                          top_ai_uses  \
# 0      Generative AI | Chatbot Q&A | Organizing Data
# 1  Generative AI | Chatbot Q&A | Translate / Tran...
# 2      Generative AI | Chatbot Q&A | Organizing Data
# 3  Generative AI | Chatbot Q&A | Translate / Tran...
# 4         Generative AI | Other AI Use | Chatbot Q&A
#
#                                         top_ai_wants  \
# 0  Virtual Assistant | Interpreting Data | Predic...
# 1  Organizing Data | Predictive AI | Virtual Assi...
# 2  Generative AI | Organizing Data | Virtual Assi...
# 3  Organizing Data | Virtual Assistant | Generati...
# 4    Generative AI | Organizing Data | Other AI Want
#
#                                            top_risks
# 0  Biased AI Decisions | IP / Plagiarism | Data B...
# 1  IP / Plagiarism | Biased AI Decisions | Data B...
# 2  Biased AI Decisions | Data Breaches | IP / Pla...
# 3  Data Breaches | IP / Plagiarism | Biased AI De...
# 4  Data Breaches | Biased AI Decisions | IP / Pla...

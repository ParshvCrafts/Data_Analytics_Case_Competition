# %% [markdown]
# # Stage 6: Want-Use Gap Index
#
# This notebook turns the gap between AI demand and actual use into a simple metric we can explain on one slide and defend in Q&A.

# %%
import sys
import warnings
from pathlib import Path
from IPython.display import display

warnings.filterwarnings("ignore")

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT / "scripts"))

from analysis_utils import notebook_setup

df = notebook_setup()
print(f"Loaded prepared analysis frame with shape: {df.shape}")
# Out:
# Loaded prepared analysis frame with shape: (930, 96)

# %% [markdown]
# ## Section 6.1 - Compute the Want-Use Gap and rank unmet needs

# %%
from stage6_want_use_gap_index import run_wug_core

wug_results = run_wug_core(df)
display(wug_results["gap_table"])
display(wug_results["wug_by_cluster"])
# Out:
#                  use_case  use_rate  want_rate       gap
# 0         Organizing Data  0.191398   0.603226  0.411828
# 1           Predictive AI  0.111828   0.517204  0.405376
# 2       Virtual Assistant  0.161290   0.556989  0.395699
# 3       Interpreting Data  0.152688   0.498925  0.346237
# 4  Translate / Transcribe  0.244086   0.390323  0.146237
# 5             Chatbot Q&A  0.326882   0.394624  0.067742
# 6            Other AI Use  0.087097   0.118280  0.031183
# 7           Generative AI  0.538710   0.549462  0.010753
#    cluster_label      mean  median  count
# 0   AI Consumers  1.806883     2.0    523
# 1    AI Skeptics  0.739437     0.0    142
# 2  Late Adopters  2.407547     2.0    265

# %% [markdown]
# ## Section 6.2 - Turn the WUG into a 2x2 intervention framework

# %%
from stage6_want_use_gap_index import run_segmentation

segment_results = run_segmentation(df)
display(segment_results["segment_summary"])
display(segment_results["segment_matrix"])
# Out:
#            wug_segment  count        pct              segment  \
# 0     Activation-ready    135  14.516129     Activation-ready
# 1  Already-well-served    193  20.752688  Already-well-served
# 2           Disengaged    264  28.387097           Disengaged
# 3    Foundation-needed    209  22.473118    Foundation-needed
# 4        Middle-ground    129  13.870968        Middle-ground
#
#                                       recommendation
# 0  Fund pilot programs and peer-learning cohorts,...
# 1  Use these nonprofits as demonstration sites an...
# 2  Start with low-stakes AI literacy and data bas...
# 3  Fund data infrastructure first, especially clo...
# 4  Offer light-touch technical assistance and dia...
#             High WUG  Low WUG
# High infra       135      193
# Low infra        209      264

# %% [markdown]
# ## Section 6.3 - Build a memorable signature visualization

# %%
from stage6_want_use_gap_index import run_signature_sankey

sankey_results = run_signature_sankey(df)
sankey_results["signature_sankey_paths"]
# Out:
# {'html': WindowsPath('c:/Users/p1a2r/OneDrive/Desktop/Git Hub Projects/Data Analystics Case Competition/outputs/figures/fig_06_signature_sankey.html')}
